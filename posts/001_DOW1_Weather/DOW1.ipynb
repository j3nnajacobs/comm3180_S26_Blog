# %% [raw]
# ---
# title: "Data set of the Week #1: The Weather in Philadelphia"
# author: "Jenna"
# date: "1/28/2026"
# categories:
#   - DOW
#   - Weather
# ---

# %% [markdown]
# #### My post

# %%
print('This is some code.')
# Out:
# This is some code.
